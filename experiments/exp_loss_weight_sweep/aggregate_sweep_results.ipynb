# %% [markdown]
# # ML-JET — Loss-Weight Sweep Aggregator (Notebook)
#
# This notebook scans your sweep outputs under:
#
# ```
# experiments/exp_loss_weight_sweep/training_output/
# ```
#
# It collects per-run metrics from `training_summary.json`, builds a table with the columns needed for your paper, and then reports the **best run per model family** (ConvNeXt, EfficientNet, ViT, Swin, Mamba).
#
# **Columns generated:**
#
# - **Model (Initialization)** — inferred from `model_tag` / folder name
# - **Batch** — `batch_size`
# - **LR** — `learning_rate`
# - **Total_Acc** — `best_accuracy`
# - **Energy (Acc, Prec, Rec, F1)**
# - **αs (Acc, Prec, Rec, F1)**
# - **Q0 (Acc, Prec, Rec, F1)**
#
# You can customize the ranking logic if needed.

# %%
# --- CONFIG ---
ROOT = "training_output/"   # path to run folders
OUT_DIR = ""                # where to write CSVs

# If running from a different CWD, you can set absolute paths:
# ROOT = "/wsu/home/.../experiments/exp_loss_weight_sweep/training_output"
# OUT_DIR = "/wsu/home/.../experiments/exp_loss_weight_sweep"

# %%
import os, json, re
from pathlib import Path
import pandas as pd

def load_json(p):
    try:
        with open(p, "r") as f:
            return json.load(f)
    except Exception as e:
        print(f"[WARN] Failed to read {p}: {e}")
        return None

FAMILY_PATTERNS = [
    (re.compile(r'efficientnet', re.I), 'EfficientNet'),
    (re.compile(r'convnext', re.I),     'ConvNeXt'),
    (re.compile(r'\bvit\b', re.I),      'ViT'),
    (re.compile(r'comer', re.I),        'ViT'),      # ViT-CoMer
    (re.compile(r'swin', re.I),         'Swin'),
    (re.compile(r'mamba', re.I),        'Mamba'),
]

def infer_family(model_tag: str, fallback: str) -> str:
    key = (model_tag or fallback or "").lower()
    for pat, fam in FAMILY_PATTERNS:
        if pat.search(key):
            return fam
    return "Other"

def get_nested(d, path, default=None):
    cur = d
    for k in path.split("."):
        if not isinstance(cur, dict) or k not in cur:
            return default
        cur = cur[k]
    return cur

def tuple4(d, base):
    """Return (acc, prec, rec, f1) for a head or (None,..) if missing."""
    return (
        get_nested(d, f"{base}.accuracy"),
        get_nested(d, f"{base}.precision"),
        get_nested(d, f"{base}.recall"),
        get_nested(d, f"{base}.f1"),
    )

ROOT = Path(ROOT)
OUT_DIR = Path(OUT_DIR)
OUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
rows = []
for run_dir in sorted(ROOT.iterdir()):
    if not run_dir.is_dir():
        continue
    summary_path = run_dir / "training_summary.json"
    if not summary_path.exists():
        continue

    js = load_json(summary_path)
    if js is None:
        continue

    model_tag = js.get("model_tag") or run_dir.name
    family = infer_family(model_tag, run_dir.name)

    # Scalars
    batch = js.get("batch_size")
    lr    = js.get("learning_rate")
    total_acc = js.get("best_accuracy")

    # Per-head tuples
    e_acc, e_prec, e_rec, e_f1 = tuple4(js, "best_model_metrics.energy")
    a_acc, a_prec, a_rec, a_f1 = tuple4(js, "best_model_metrics.alpha")
    q_acc, q_prec, q_rec, q_f1 = tuple4(js, "best_model_metrics.q0")

    rows.append({
        "family": family,
        "model_tag": model_tag,
        "run_dir": str(run_dir),
        "batch": batch,
        "lr": lr,
        "Total_Acc": total_acc,
        "Energy_Acc": e_acc, "Energy_Prec": e_prec, "Energy_Rec": e_rec, "Energy_F1": e_f1,
        "Alpha_Acc": a_acc,  "Alpha_Prec": a_prec,  "Alpha_Rec": a_rec,  "Alpha_F1": a_f1,
        "Q0_Acc": q_acc,     "Q0_Prec": q_prec,     "Q0_Rec": q_rec,     "Q0_F1": q_f1,
    })

import pandas as pd
df = pd.DataFrame(rows)
print(f"[OK] Collected {len(df)} runs from {ROOT}")
df.head()
display(df)
# Out:
# [OK] Collected 51 runs from training_output
#           family                                          model_tag  \
# 0       ConvNeXt       ConvNeXt_Gaussian_g500__lw-S10_q0_alpha_pair
# 1       ConvNeXt             ConvNeXt_Gaussian_g500__lw-S1_balanced
# 2       ConvNeXt             ConvNeXt_Gaussian_g500__lw-S1_balanced
# 3       ConvNeXt              ConvNeXt_Gaussian_g500__lw-S2_q0_mild
# 4       ConvNeXt               ConvNeXt_Gaussian_g500__lw-S3_q0_mid
# 5       ConvNeXt            ConvNeXt_Gaussian_g500__lw-S4_q0_strong
# 6       ConvNeXt               ConvNeXt_Gaussian_g500__lw-S5_q0_max
# 7       ConvNeXt           ConvNeXt_Gaussian_g500__lw-S6_alpha_mild
# 8       ConvNeXt         ConvNeXt_Gaussian_g500__lw-S7_alpha_strong
# 9       ConvNeXt          ConvNeXt_Gaussian_g500__lw-S8_energy_bump
# 10      ConvNeXt         ConvNeXt_Gaussian_g500__lw-S9_q0_very_mild
# 11  EfficientNet            EfficientNet_g500__lw-S10_q0_alpha_pair
# 12  EfficientNet                  EfficientNet_g500__lw-S1_balanced
# 13  EfficientNet                   EfficientNet_g500__lw-S2_q0_mild
# 14  EfficientNet                    EfficientNet_g500__lw-S3_q0_mid
# 15  EfficientNet                 EfficientNet_g500__lw-S4_q0_strong
# 16  EfficientNet                    EfficientNet_g500__lw-S5_q0_max
# 17  EfficientNet                EfficientNet_g500__lw-S6_alpha_mild
# 18  EfficientNet              EfficientNet_g500__lw-S7_alpha_strong
# 19  EfficientNet               EfficientNet_g500__lw-S8_energy_bump
# 20  EfficientNet              EfficientNet_g500__lw-S9_q0_very_mild
# 21         Mamba  MambaOut_base_plus_rw_lrp_12_rlrp_4__lw-S10_q0...
# 22         Mamba  MambaOut_base_plus_rw_lrp_12_rlrp_4__lw-S1_bal...
# 23         Mamba  MambaOut_base_plus_rw_lrp_12_rlrp_4__lw-S2_q0_...
# 24         Mamba  MambaOut_base_plus_rw_lrp_12_rlrp_4__lw-S3_q0_mid
# 25         Mamba  MambaOut_base_plus_rw_lrp_12_rlrp_4__lw-S4_q0_...
# 26         Mamba  MambaOut_base_plus_rw_lrp_12_rlrp_4__lw-S5_q0_max
# 27         Mamba  MambaOut_base_plus_rw_lrp_12_rlrp_4__lw-S6_alp...
# 28         Mamba  MambaOut_base_plus_rw_lrp_12_rlrp_4__lw-S7_alp...
# 29         Mamba  MambaOut_base_plus_rw_lrp_12_rlrp_4__lw-S8_ene...
# 30         Mamba  MambaOut_base_plus_rw_lrp_12_rlrp_4__lw-S9_q0_...
# 31          Swin                    Swin_g500__lw-S10_q0_alpha_pair
# 32          Swin                          Swin_g500__lw-S1_balanced
# 33          Swin                           Swin_g500__lw-S2_q0_mild
# 34          Swin                            Swin_g500__lw-S3_q0_mid
# 35          Swin                         Swin_g500__lw-S4_q0_strong
# 36          Swin                            Swin_g500__lw-S5_q0_max
# 37          Swin                        Swin_g500__lw-S6_alpha_mild
# 38          Swin                      Swin_g500__lw-S7_alpha_strong
# 39          Swin                       Swin_g500__lw-S8_energy_bump
# 40          Swin                      Swin_g500__lw-S9_q0_very_mild
# 41         Other  ViT_tiny_patch16_224_gaussian_lrp_60_rlrp_12_q...
# 42         Other  ViT_tiny_patch16_224_gaussian_lrp_60_rlrp_12_q...
# 43         Other  ViT_tiny_patch16_224_gaussian_lrp_60_rlrp_12_q...
# 44         Other  ViT_tiny_patch16_224_gaussian_lrp_60_rlrp_12_q...
# 45         Other  ViT_tiny_patch16_224_gaussian_lrp_60_rlrp_12_q...
# 46         Other  ViT_tiny_patch16_224_gaussian_lrp_60_rlrp_12_q...
# 47         Other  ViT_tiny_patch16_224_gaussian_lrp_60_rlrp_12_q...
# 48         Other  ViT_tiny_patch16_224_gaussian_lrp_60_rlrp_12_q...
# 49         Other  ViT_tiny_patch16_224_gaussian_lrp_60_rlrp_12_q...
# 50         Other  ViT_tiny_patch16_224_gaussian_lrp_60_rlrp_12_q...
#
#                                               run_dir  batch      lr  \
# 0   training_output/ConvNeXt_Gaussian_g500__lw-S10...     32  0.0001
# 1   training_output/ConvNeXt_Gaussian_g500__lw-S1_...     32  0.0001
# 2   training_output/ConvNeXt_Gaussian_g500__lw-S1_...     32  0.0001
# 3   training_output/ConvNeXt_Gaussian_g500__lw-S2_...     32  0.0001
# 4   training_output/ConvNeXt_Gaussian_g500__lw-S3_...     32  0.0001
# 5   training_output/ConvNeXt_Gaussian_g500__lw-S4_...     32  0.0001
# 6   training_output/ConvNeXt_Gaussian_g500__lw-S5_...     32  0.0001
# 7   training_output/ConvNeXt_Gaussian_g500__lw-S6_...     32  0.0001
# 8   training_output/ConvNeXt_Gaussian_g500__lw-S7_...     32  0.0001
# 9   training_output/ConvNeXt_Gaussian_g500__lw-S8_...     32  0.0001
# 10  training_output/ConvNeXt_Gaussian_g500__lw-S9_...     32  0.0001
# 11  training_output/EfficientNet_g500__lw-S10_q0_a...     32  0.0100
# 12  training_output/EfficientNet_g500__lw-S1_balan...     32  0.0100
# 13  training_output/EfficientNet_g500__lw-S2_q0_mi...     32  0.0100
# 14  training_output/EfficientNet_g500__lw-S3_q0_mi...     32  0.0100
# 15  training_output/EfficientNet_g500__lw-S4_q0_st...     32  0.0100
# 16  training_output/EfficientNet_g500__lw-S5_q0_ma...     32  0.0100
# 17  training_output/EfficientNet_g500__lw-S6_alpha...     32  0.0100
# 18  training_output/EfficientNet_g500__lw-S7_alpha...     32  0.0100
# 19  training_output/EfficientNet_g500__lw-S8_energ...     32  0.0100
# 20  training_output/EfficientNet_g500__lw-S9_q0_ve...     32  0.0100
# 21  training_output/MambaOut_base_plus_rw_lrp_12_r...     16  0.0001
# 22  training_output/MambaOut_base_plus_rw_lrp_12_r...     16  0.0001
# 23  training_output/MambaOut_base_plus_rw_lrp_12_r...     16  0.0001
# 24  training_output/MambaOut_base_plus_rw_lrp_12_r...     16  0.0001
# 25  training_output/MambaOut_base_plus_rw_lrp_12_r...     16  0.0001
# 26  training_output/MambaOut_base_plus_rw_lrp_12_r...     16  0.0001
# 27  training_output/MambaOut_base_plus_rw_lrp_12_r...     16  0.0001
# 28  training_output/MambaOut_base_plus_rw_lrp_12_r...     16  0.0001
# 29  training_output/MambaOut_base_plus_rw_lrp_12_r...     16  0.0001
# 30  training_output/MambaOut_base_plus_rw_lrp_12_r...     16  0.0001
# 31  training_output/Swin_g500__lw-S10_q0_alpha_pai...     32  0.0001
# 32  training_output/Swin_g500__lw-S1_balanced_bs32...     32  0.0001
# 33  training_output/Swin_g500__lw-S2_q0_mild_bs32_...     32  0.0001
# 34  training_output/Swin_g500__lw-S3_q0_mid_bs32_e...     32  0.0001
# 35  training_output/Swin_g500__lw-S4_q0_strong_bs3...     32  0.0001
# 36  training_output/Swin_g500__lw-S5_q0_max_bs32_e...     32  0.0001
# 37  training_output/Swin_g500__lw-S6_alpha_mild_bs...     32  0.0001
# 38  training_output/Swin_g500__lw-S7_alpha_strong_...     32  0.0001
# 39  training_output/Swin_g500__lw-S8_energy_bump_b...     32  0.0001
# 40  training_output/Swin_g500__lw-S9_q0_very_mild_...     32  0.0001
# 41  training_output/ViT_tiny_patch16_224_gaussian_...     32  0.0001
# 42  training_output/ViT_tiny_patch16_224_gaussian_...     32  0.0001
# 43  training_output/ViT_tiny_patch16_224_gaussian_...     32  0.0001
# 44  training_output/ViT_tiny_patch16_224_gaussian_...     32  0.0001
# 45  training_output/ViT_tiny_patch16_224_gaussian_...     32  0.0001
# 46  training_output/ViT_tiny_patch16_224_gaussian_...     32  0.0001
# 47  training_output/ViT_tiny_patch16_224_gaussian_...     32  0.0001
# 48  training_output/ViT_tiny_patch16_224_gaussian_...     32  0.0001
# 49  training_output/ViT_tiny_patch16_224_gaussian_...     32  0.0001
# 50  training_output/ViT_tiny_patch16_224_gaussian_...     32  0.0001
#
#     Total_Acc  Energy_Acc  Energy_Prec  Energy_Rec  Energy_F1  Alpha_Acc  \
# 0    0.680556    1.000000     1.000000    1.000000   1.000000   0.937500
# 1    0.600000    1.000000     1.000000    1.000000   1.000000   0.950000
# 2    0.670139    1.000000     1.000000    1.000000   1.000000   0.937500
# 3    0.673611    1.000000     1.000000    1.000000   1.000000   0.937500
# 4    0.677083    1.000000     1.000000    1.000000   1.000000   0.940972
# 5    0.673611    1.000000     1.000000    1.000000   1.000000   0.934028
# 6    0.690972    1.000000     1.000000    1.000000   1.000000   0.937500
# 37    0.895856   0.895833  0.895731  0.677083  0.674624  0.677083  0.675676
# 38    0.889628   0.885417  0.885156  0.663194  0.661501  0.663194  0.657511
# 39    0.889884   0.885417  0.885142  0.673611  0.681319  0.673611  0.667969
# 40    0.873139   0.871528  0.870924  0.663194  0.652831  0.663194  0.652841
# 41    0.944211   0.944444  0.944259  0.732639  0.755735  0.732639  0.726115
# 42    0.947835   0.944444  0.943963  0.763889  0.770406  0.763889  0.760030
# 43    0.961941   0.961806  0.961821  0.767361  0.771524  0.767361  0.768891
# 44    0.922100   0.916667  0.916960  0.704861  0.712516  0.704861  0.707935
# 45    0.929485   0.927083  0.927293  0.743056  0.734802  0.743056  0.737667
# 46    0.911945   0.909722  0.909622  0.704861  0.691421  0.704861  0.688452
# 47    0.937492   0.937500  0.937176  0.750000  0.763505  0.750000  0.754353
# 48    0.951373   0.951389  0.951157  0.729167  0.734675  0.729167  0.721491
# 49    0.932840   0.930556  0.929944  0.732639  0.757027  0.732639  0.739697
# 50    0.951882   0.951389  0.951566  0.756944  0.753417  0.756944  0.753704

# %%
from os import path


full_csv = path.join(OUT_DIR, "aggregate_results_detailed.csv")
df.to_csv(full_csv, index=False)
print(f"[OK] wrote {full_csv}")

# Display (if running in a notebook UI that supports DataFrames)
try:
    from caas_jupyter_tools import display_dataframe_to_user
    display_dataframe_to_user("Loss-Weight Sweep — Full Results", df)
except Exception as e:
    print("[INFO] display_dataframe_to_user not available in this environment.")
# Out:
# [OK] wrote ./aggregate_results_detailed.csv
# [INFO] display_dataframe_to_user not available in this environment.

# %%
# Rank by Total_Acc, tie-break on Q0_F1 (most challenging head)
df_numeric = df.copy()
for c in ["Total_Acc","Q0_F1"]:
    df_numeric[c] = pd.to_numeric(df_numeric[c], errors="coerce")

best_rows = []
for fam, sub in df_numeric.groupby("family"):
    sub = sub.copy()
    sub["_rank_key"] = list(zip(sub["Total_Acc"].fillna(-1), sub["Q0_F1"].fillna(-1)))
    best_idx = sub["_rank_key"].idxmax()
    best_rows.append(df.loc[best_idx])

best_df = pd.DataFrame(best_rows).sort_values("family")
best_csv = path.join(OUT_DIR, "best_per_family_detailed.csv")
best_df.to_csv(best_csv, index=False)
print(f"[OK] wrote {best_csv}")
best_df[["family","model_tag","batch","lr","Total_Acc",
         "Energy_Acc","Energy_Prec","Energy_Rec","Energy_F1",
         "Alpha_Acc","Alpha_Prec","Alpha_Rec","Alpha_F1",
         "Q0_Acc","Q0_Prec","Q0_Rec","Q0_F1"]]
# Out:
# [OK] wrote ./best_per_family_detailed.csv
#           family                                          model_tag  batch  \
# 6       ConvNeXt               ConvNeXt_Gaussian_g500__lw-S5_q0_max     32
# 18  EfficientNet              EfficientNet_g500__lw-S7_alpha_strong     32
# 24         Mamba  MambaOut_base_plus_rw_lrp_12_rlrp_4__lw-S3_q0_mid     16
# 43         Other  ViT_tiny_patch16_224_gaussian_lrp_60_rlrp_12_q...     32
# 37          Swin                        Swin_g500__lw-S6_alpha_mild     32
#
#         lr  Total_Acc  Energy_Acc  Energy_Prec  Energy_Rec  Energy_F1  \
# 6   0.0001   0.690972         1.0          1.0         1.0        1.0
# 18  0.0100   0.739583         1.0          1.0         1.0        1.0
# 24  0.0001   0.690972         1.0          1.0         1.0        1.0
# 43  0.0001   0.729167         1.0          1.0         1.0        1.0
# 37  0.0001   0.572917         1.0          1.0         1.0        1.0
#
#     Alpha_Acc  Alpha_Prec  Alpha_Rec  Alpha_F1    Q0_Acc   Q0_Prec    Q0_Rec  \
# 6    0.937500    0.938389   0.937500  0.936980  0.753472  0.751971  0.753472
# 18   0.954861    0.958062   0.954861  0.955222  0.784722  0.796988  0.784722
# 24   0.944444    0.944934   0.944444  0.944621  0.746528  0.758722  0.746528
# 43   0.961806    0.961941   0.961806  0.961821  0.767361  0.771524  0.767361
# 37   0.895833    0.895856   0.895833  0.895731  0.677083  0.674624  0.677083
#
#        Q0_F1
# 6   0.751455
# 18  0.786834
# 24  0.749777
# 43  0.768891
# 37  0.675676

# %%
# --- Add loss weights from run_dir name ---
import re

def parse_weights_from_dir(name: str):
    m = re.search(
        r'energy[_]?loss[_]?output[_-]?([0-9.]+).*?alpha[_]?output[_-]?([0-9.]+).*?q0[_]?output[_-]?([0-9.]+)',
        name,
        flags=re.I,
    )
    if m:
        return float(m.group(1)), float(m.group(2)), float(m.group(3))
    return None, None, None

best_df = best_df.copy()
best_df["w_energy"], best_df["w_alpha"], best_df["w_q0"] = zip(
    *best_df["run_dir"].map(parse_weights_from_dir)
)

# Save again with weights included
best_csv = path.join(OUT_DIR, "best_per_family_detailed_with_weights.csv")
best_df.to_csv(best_csv, index=False)
print(f"[OK] wrote {best_csv}")

# best_df[
#     ["family","model_tag","batch","lr","Total_Acc",
#      "Energy_Acc","Energy_Prec","Energy_Rec","Energy_F1",
#      "Alpha_Acc","Alpha_Prec","Alpha_Rec","Alpha_F1",
#      "Q0_Acc","Q0_Prec","Q0_Rec","Q0_F1",
#      "w_energy","w_alpha","w_q0"]
# ]
best_df[
    ["family",
     "Energy_Prec","Energy_Rec",
     "Alpha_Prec","Alpha_Rec",
     "Q0_Prec","Q0_Rec",
     "w_energy","w_alpha","w_q0"]
]
# Out:
# [OK] wrote ./best_per_family_detailed_with_weights.csv
#           family  Energy_Prec  Energy_Rec  Alpha_Prec  Alpha_Rec   Q0_Prec  \
# 6       ConvNeXt          1.0         1.0    0.938389   0.937500  0.751971
# 18  EfficientNet          1.0         1.0    0.958062   0.954861  0.796988
# 24         Mamba          1.0         1.0    0.944934   0.944444  0.758722
# 43         Other          1.0         1.0    0.961941   0.961806  0.771524
# 37          Swin          1.0         1.0    0.895856   0.895833  0.674624
#
#       Q0_Rec  w_energy  w_alpha  w_q0
# 6   0.753472       0.4      0.6   2.0
# 18  0.784722       0.6      1.6   0.8
# 24  0.746528       0.6      0.8   1.6
# 43  0.767361       0.8      0.8   1.4
# 37  0.677083       0.8      1.2   1.0
